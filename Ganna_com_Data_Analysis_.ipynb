# %% [markdown]
# <a href="https://colab.research.google.com/github/AishwaryaKyasari/Datascience/blob/main/Ganna_com_Data_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AshishJangra27/Gaana-Data-Analysis
# Out:
# fatal: destination path 'Gaana-Data-Analysis' already exists and is not an empty directory.

# %%
import pandas as pd
df=pd.read_csv("Gaana-Data-Analysis/songs.csv")

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df.size
# Out:
# 248130

# %%
df.shape
# Out:
# (41355, 6)

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %% [markdown]
# Check Null Values in the dataframe

# %%
df.isnull() # is null checks if data consistes on null value or not and False indicates that dataset does not contains null values
# Out:
#         name  singer  singer_id  duration   link  language
# 0      False   False      False     False  False     False
# 1      False   False      False     False  False     False
# 2      False   False      False     False  False     False
# 3      False   False      False     False  False     False
# 4      False   False      False     False  False     False
# ...      ...     ...        ...       ...    ...       ...
# 41350  False   False      False     False  False     False
# 41351  False   False      False     False  False     False
# 41352  False   False      False     False  False     False
# 41353  False   False      False     False  False     False
# 41354  False   False      False     False  False     False
#
# [41355 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# Data preprocessing
#
# ```
# `# This is formatted as code`
# ```
#
#
# Dealing with *duration*

# %%
df['duration'].head()
# Out:
# 0    05:00
# 1    06:26
# 2    03:41
# 3    04:26
# 4    05:39
# Name: duration, dtype: object

# %%
duration_=[]
for i in df['duration']:
  t=i.split(":")
  duration_.append(int(t[0])*60 + int(t[1]))

# %%
df['duration']=duration_

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id  duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1       300
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1       386
# 2                       /artist/jagjeet-singh-1       221
# 3                          /artist/chitra-singh       266
# 4                       /artist/jagjeet-singh-1       339
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# ...

# %% [markdown]
# ### 3.Data Analysis
# #####3.1 what is average duration of a song

# %%
int(df['duration'].sum()/len(df['duration']))
# Out:
# 295

# %% [markdown]
# ##### 3.2 how many languages of songs are there in the datasets?

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
#OR
len(set(df['language']))
# Out:
# 16

# %% [markdown]
# #####3.3 how many panjabi songs are there?

# %%
len(df[df['language']=="Punjabi"])
# Out:
# 3818

# %% [markdown]
# ### 3.4Number of songs in each **language**

# %%
list_of_songs=[]
for i in set(df['language']):
  cnt=0;
  for j in df['language']:
    if i==j:
      cnt+=1
  list_of_songs.append([i,cnt])

# %%
for i in df['language'].unique():
  print(i,len(df[df['language']==i]))
# Out:
# Urdu 3116
# Gujarati 2115
# Tamil 4677
# Kannada 3559
# Rajasthani 541
# Haryanvi 228
# Punjabi 3818
# Hindi 4993
# Old 4993
# Malayalam 479
# Marathi 4699
# Telugu 4996
# Odia 940
# Bhojpuri 519
# Assamese 724
# Bengali 958

# %% [markdown]
# #####3.6 Average duration of songs in each language

# %%
for i in df['language'].unique():
  print(i,int((df[df['language']==i]).mean()))
# Out:
# Urdu 407
# Gujarati 271
# Tamil 270
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Kannada 250
# Rajasthani 291
# Haryanvi 320
# Punjabi 324
# Hindi 307
# Old 307
# Malayalam 242
# Marathi 281
# Telugu 279
# Odia 257
# Bhojpuri 357
# Assamese 228
# Bengali 255

# %% [markdown]
# ##### 3.7 how many singers are there in datasets

# %%
singers=[]
for singer in df['singer']:
  singers +=singer.split("|")

# %%
len(set(singers))
# Out:
# 3940

# %% [markdown]
# #####3.8 who has sung the most number of songs

# %%
from tqdm import tqdm

# %%
no_of_song=[]
for singer in df['singer'].unique():
  cnt=0;
  for sing in df['singer']:
    if singer in sing:    # if we use == insted of in then we can check out the songs which alone person sang 
      cnt+=1
  no_of_song.append([singer,cnt])
no_of_song
# Out:
# [['Chitra Singh|Jagjit Singh', 45],
#  ['Jagjit Singh', 255],
#  ['Chitra Singh', 108],
#  ['Jagjit Kaur', 22],
#  ['Chitra Singh|Naseeruddin Shah', 4],
#  ['Naseeruddin Shah|Jagjit Singh', 2],
#  ['Jagjit Singh|Naseeruddin Shah', 1],
#  ['Asha Bhosle|Ghulam Ali', 1],
#  ['Chitra Singh|Gulzar|Naseeruddin Shah|Vinod Sehgal|Jagjit Singh', 2],
#  ['Mohammed Rafi|Suman Kalyanpur', 43],
#  ['Jagjit Singh|Chitra Singh', 23],
#  ['Begum Akhtar', 22],
#  ['Bhupinder Singh', 157],
#  ['C.H. Atma', 3],
#  ['Aziz Miyan Qawwal|Sabri Brothers', 1],
#  ['Naseeruddin Shah|Vinod Sehgal', 3],
#  ['Ustad Ali Ahmed Hussain|Mohd. Hussain|Chorus', 8],
#  ['Mohammed Rafi', 2133],
#  ["Chitra Singh|Jagjit Singh|Supported By Talents 80'S", 1],
#  ['Hussain Bakhash Khan|Mukhtar Begum', 1],
#  ['Naseeruddin Shah|Chitra Singh', 1],
#  ['Lata Mangeshkar', 3056],
#  ['Talat Aziz', 22],
#  ['Ashok Khosla', 13],
#  ['Lata Mangeshkar|Chorus', 61],
#  ['Aziz Miyan Qawwal', 38],
# ...

# %%
no_of_song[:10]
sol=sorted(no_of_song,key=lambda x: x[1],reverse=True)
sol[0]
# OR seperate out songs and then songs.sort_values(by='songs',ascending=False).head()
# Out:
# ['S. P. Balasubrahmanyam', 3659]

# %% [markdown]
# ##### 3.9 singer who played most number of songs in each language

# %%
# lets check who sang most no.of songs in kannada 
for lang in df['language'].unique():
    df_=df[df['language']==lang]
    
    all_singer=[]
    for singer in df_['singer'].unique():
      all_singer+=singer.split("|")
      no_of_song=[]
      for sang in all_singer:
          cnt=0;
          for sing in df_['singer']:
            if sang in sing:    # if we use == insted of in then we can check out the songs which alone person sang 
                cnt+=1
          no_of_song.append([lang,sang,cnt])
          print([sang,cnt,lang])
      sol=sorted(no_of_song,key=lambda x: x[2],reverse=True)[0]
    #print(all_singer,lang)  prints all the singers in perticular language
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Anuradha Paudwal', 61, 'Gujarati']
# ['Bappi Lahiri', 2, 'Gujarati']
# ['Rajani Mehta', 19, 'Gujarati']
# ['Govind Boricha', 2, 'Gujarati']
# ['Naresh Kanodia', 9, 'Gujarati']
# ['Anand kumar C.', 37, 'Gujarati']
# ['Pushpa Shah', 1, 'Gujarati']
# ['Usha Rege', 4, 'Gujarati']
# ['Aarti Mukherji', 23, 'Gujarati']
# ['Chorus', 437, 'Gujarati']
# ['Diwaliben Bhil', 52, 'Gujarati']
# ['Usha Mangeshkar', 214, 'Gujarati']
# ['Chorus', 437, 'Gujarati']
# ['Mukesh', 21, 'Gujarati']
# ['Suman Kalyanpur', 63, 'Gujarati']
# ['Deepak Kumar Pandit', 8, 'Gujarati']
# ['Meena Kapoor', 2, 'Gujarati']
# ['Chetan Gadhvi', 1, 'Gujarati']
# ['Anand kumar C.', 37, 'Gujarati']
# ['Aziz Naazan', 2, 'Gujarati']
# ['Chorus', 437, 'Gujarati']
# ['Kanchan', 5, 'Gujarati']
# ['Manhar Udhas', 27, 'Gujarati']
# ['Ghanshyam Nayak', 3, 'Gujarati']
# ['Chorus', 437, 'Gujarati']
# ['Asha Bhosle', 288, 'Gujarati']
# ['Kishore Kumar', 5, 'Gujarati']
# ...

# %%
for lang in df['language'].unique():
    df_=df[df['language']==lang]
    
    all_singer=[]
    for singer in df_['singer'].unique():
      all_singer+=singer.split("|")
      no_of_song=[]
      for sang in all_singer:
          cnt=0;
          for sing in df_['singer']:
            if sang in sing:    # if we use == insted of in then we can check out the songs which alone person sang 
                cnt+=1
          no_of_song.append([lang,sang,cnt])
      sol=sorted(no_of_song,key=lambda x: x[2],reverse=True)[0]
print(sol)
# Out:
# ['Bengali', 'Kishore Kumar', 140]

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...
